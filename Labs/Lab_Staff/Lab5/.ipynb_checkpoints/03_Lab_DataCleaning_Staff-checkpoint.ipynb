# %% [markdown]
# # Engineering Analytics and Machine Learning Lab 23
# ## for Specialist Diploma in Internet of Things
#
# ### Author’s Name: Teo Kok Keong
#
# ### Property of Temasek Polytechnic, Copyright ©.
# ### For circulation within Temasek Polytechnic only.
#
#
#
# # 1 Data Cleaning

# %% [markdown]
# # 1.1  Missing Data
#
# Missing Data in Pandas was handled in two ways, the None and NaN.

# %%
import numpy as np
import pandas as pd

#Let's look at None as a python object
x = np.array([1, None, 3, 2])
x
# Out:
# array([1, None, 3, 2], dtype=object)

# %%
#NaN is recognized by all systems that use standard IEEE floating-point representation
y=np.array([1,np.nan,3,4])
print(y.dtype)
# Out:
# float64

# %%
#anything that have arithmetic operation with nan the result is nan

result=2+np.nan
print(result)
result2=np.nan/2
print(result2)
# Out:
# nan
# nan

# %% [markdown]
# Pandas treat None and NaN essentially interchangeable for indicating missing or null values. To faciliate this convention, there are several useful methods to due with null values in Pandas data structure.

# %%
data=pd.Series([1,np.nan,'hello',None])
print(data)
# Out:
# 0        1
# 1      NaN
# 2    hello
# 3     None
# dtype: object

# %%
#we can detect null values using the isnull() method
print("isnull result")
print(data.isnull()) 

#we can do the opposite using the notnull() method
print("notnull  result")
print(data.notnull())
# Out:
# isnull result
# 0    False
# 1     True
# 2    False
# 3     True
# dtype: bool
# notnull  result
# 0     True
# 1    False
# 2     True
# 3    False
# dtype: bool

# %% [markdown]
# ## 1.2 Data Selection in Series
#
# A Series object acts in many ways like a one-dimensional NumPy array, and in many ways like a standard Python dictionary. If we keep these two overlapping analogies in mind, it will help us to understand the patterns of data indexing and selection in these arrays

# %%
import pandas as pd
data = pd.Series([0.25, 0.5, 0.75, 1.0],index=['a', 'b', 'c', 'd'])
data
# Out:
# a    0.25
# b    0.50
# c    0.75
# d    1.00
# dtype: float64

# %%
# we can select any value by

data['b']
# Out:
# 0.5

# %%
#dictionary like expression 

print('a' in data)   #check key 'a' exist

print('w' in data)    #check key 'w' exist

print(data.keys())   

print(list(data.items()))

data['e']=1.25      #modify value to 1.25 with key='e'
print(data)
# Out:
# True
# False
# Index(['a', 'b', 'c', 'd'], dtype='object')
# [('a', 0.25), ('b', 0.5), ('c', 0.75), ('d', 1.0)]
# a    0.25
# b    0.50
# c    0.75
# d    1.00
# e    1.25
# dtype: float64

# %%
#also can be slice and select by Numpy array

print(data['a':'c'])  #select data from key='a' to 'c'
print(data[0:2])      #select data by implicit integer index
print(data[(data>0.3)&(data<0.8)] )  #by masking only select value between 0.3 and 0.8
print(data[['a','e']])   #select only value with key='a' and 'e'
# Out:
# a    0.25
# b    0.50
# c    0.75
# dtype: float64
# a    0.25
# b    0.50
# dtype: float64
# b    0.50
# c    0.75
# dtype: float64
# a    0.25
# e    1.25
# dtype: float64

# %%
#these selection can be use to mask out missing value
#lets redefine the data we have previously
data=pd.Series([1,np.nan,'hello',None])
print(data)
# Out:
# 0        1
# 1      NaN
# 2    hello
# 3     None
# dtype: object

# %%
print(data[data.notnull()])   #remove all the missing data
# Out:
# 0        1
# 2    hello
# dtype: object

# %%
#or there is convenience methods such as dropna() which mean removes NA value
print(data.dropna())
# Out:
# 0        1
# 2    hello
# dtype: object

# %% [markdown]
# Pandas DataFrame which is usually multidimensional is a little more complicated than Pandas Series. Simply because we cannot drop single values from a DataFrame, we can only drop full rows or full columns. However, that would affected a lot of other unrelated data points which essentially greatly reduce the number of data points. How to drop is very application dependent and there is no a simple all correct answer to all situations.
#
# By default dropna() will drop all rows which any null value is present. We can dropna() of all column which any null is present by using the setting the axis='columns'

# %%
 df = pd.DataFrame([[1,      np.nan, 2],
                    [2,      3,      5],
                    [np.nan, 4,      6]])
print(df.dropna())     #drop all rolls with null value
print(df.dropna(axis='columns'))  #drop all columns with null value
# Out:
#      0    1  2
# 1  2.0  3.0  5
#    2
# 0  2
# 1  5
# 2  6

# %%
#lets see how we can clean data with finerr grain of control
df[3] = np.nan   #add a third column that is all null values
print(df)
#The default of how='any', such that any row or column (depending on the axis keyword) containing a null value will be dropped. 
#we can set how='all' that mean only drop if cany row or column is all null value
print(df.dropna(axis='columns',how='all'))
#thresh let you specify what ist he minimum number of non-null values for the row/columns to be kept
print(df.dropna(axis='rows', thresh=3))
# Out:
#      0    1  2   3
# 0  1.0  NaN  2 NaN
# 1  2.0  3.0  5 NaN
# 2  NaN  4.0  6 NaN
#      0    1  2
# 0  1.0  NaN  2
# 1  2.0  3.0  5
# 2  NaN  4.0  6
#      0    1  2   3
# 1  2.0  3.0  5 NaN

# %% [markdown]
# Sometime in certain application missing data can be replace by a certain number. In this section we are going to fill null values.

# %%
data1 = pd.Series([1, np.nan, 2, None, 3], index=list('abcde'))
print(data1)
#we can fill all null with any value such as 0 in  this example
print(data1.fillna(0))
#forward-fill to propagate the previous value value forward, mean to fill null value with value of the previous non-null value
print(data1.fillna(method='ffill'))
#the opposite would be back fill
print(data1.fillna(method='bfill'))
# Out:
# a    1.0
# b    NaN
# c    2.0
# d    NaN
# e    3.0
# dtype: float64
# a    1.0
# b    0.0
# c    2.0
# d    0.0
# e    3.0
# dtype: float64
# a    1.0
# b    1.0
# c    2.0
# d    2.0
# e    3.0
# dtype: float64
# a    1.0
# b    2.0
# c    2.0
# d    3.0
# e    3.0
# dtype: float64

# %%
#we can do similar thing with dataframe
print(df)
print(df.fillna(method='ffill',axis=1)) #in row
print(df.fillna(method='ffill',axis=0)) #in column
#if previous value not available nan would remain
# Out:
#      0    1  2   3
# 0  1.0  NaN  2 NaN
# 1  2.0  3.0  5 NaN
# 2  NaN  4.0  6 NaN
#      0    1    2    3
# 0  1.0  1.0  2.0  2.0
# 1  2.0  3.0  5.0  5.0
# 2  NaN  4.0  6.0  6.0
#      0    1  2   3
# 0  1.0  NaN  2 NaN
# 1  2.0  3.0  5 NaN
# 2  2.0  4.0  6 NaN

# %% [markdown]
# ## Exercise 1
#
# Load the data file april-2017.csv and use the head() and info() methods to understand more about the data. We want to drop the null values.
#
# 1. We cannot tolerate any null value, we  would remove any rows/columns with any null values. Rows or Column is feasible in this case?
# 2. Perform operation so that we can keep the rows/columns it does not contain all null values and forward fill the null value.

# %%
import numpy as np
import pandas as pd

ddf=pd.read_csv('april-2017.csv')
ddf.head()
# Out:
#               UTC time  3_temperature  3_humidity  3_pressure  3_pm1  3_pm25  \
# 0  2017-04-01T00:00:00            NaN         NaN         NaN    NaN     NaN
# 1  2017-04-01T01:00:00            NaN         NaN         NaN    NaN     NaN
# 2  2017-04-01T02:00:00            NaN         NaN         NaN    NaN     NaN
# 3  2017-04-01T03:00:00            NaN         NaN         NaN    NaN     NaN
# 4  2017-04-01T04:00:00            NaN         NaN         NaN    NaN     NaN
#
#    3_pm10  140_temperature  140_humidity  140_pressure    ...     \
# 0     NaN                6            92        101906    ...
# 1     NaN                6            92        101869    ...
# 2     NaN                5            94        101837    ...
# 3     NaN                5            92        101834    ...
# 4     NaN                4            94        101832    ...
#
#    857_pressure  857_pm1  857_pm25  857_pm10  895_temperature  895_humidity  \
# 0           NaN      NaN       NaN       NaN              NaN           NaN
# 1           NaN      NaN       NaN       NaN              NaN           NaN
# 2           NaN      NaN       NaN       NaN              NaN           NaN
# 3           NaN      NaN       NaN       NaN              NaN           NaN
# 4           NaN      NaN       NaN       NaN              NaN           NaN
#
#    895_pressure  895_pm1  895_pm25  895_pm10
# 0           NaN      NaN       NaN       NaN
# 1           NaN      NaN       NaN       NaN
# 2           NaN      NaN       NaN       NaN
# 3           NaN      NaN       NaN       NaN
# 4           NaN      NaN       NaN       NaN
#
# [5 rows x 337 columns]

# %%
ddf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 720 entries, 0 to 719
# Columns: 337 entries, UTC time to 895_pm10
# dtypes: float64(193), int64(143), object(1)
# memory usage: 1.9+ MB

# %%
ddf.dropna(axis='columns')
# Out:
#                 UTC time  140_temperature  140_humidity  140_pressure  \
# 0    2017-04-01T00:00:00                6            92        101906
# 1    2017-04-01T01:00:00                6            92        101869
# 2    2017-04-01T02:00:00                5            94        101837
# 3    2017-04-01T03:00:00                5            92        101834
# 4    2017-04-01T04:00:00                4            94        101832
# 5    2017-04-01T05:00:00                5            94        101833
# 6    2017-04-01T06:00:00                9            78        101842
# 7    2017-04-01T07:00:00               11            66        101831
# 8    2017-04-01T08:00:00               15            50        101798
# 9    2017-04-01T09:00:00               17            42        101745
# 10   2017-04-01T10:00:00               19            39        101701
# 11   2017-04-01T11:00:00               20            35        101651
# 12   2017-04-01T12:00:00               21            30        101580
# 13   2017-04-01T13:00:00               23            32        101507
# 14   2017-04-01T14:00:00               24            33        101443
# 15   2017-04-01T15:00:00               23            32        101395
# 16   2017-04-01T16:00:00               21            33        101383
# 17   2017-04-01T17:00:00               19            34        101403
# 18   2017-04-01T18:00:00               16            48        101447
# 19   2017-04-01T19:00:00               14            48        101481
# 20   2017-04-01T20:00:00               12            54        101498
# 21   2017-04-01T21:00:00               11            62        101525
# 22   2017-04-01T22:00:00                9            66        101554
# 23   2017-04-01T23:00:00                8            76        101559
# 24   2017-04-02T00:00:00                7            77        101540
# 25   2017-04-02T01:00:00                6            88        101528
# 26   2017-04-02T02:00:00                5            86        101524
# 27   2017-04-02T03:00:00                6            85        101523
# 28   2017-04-02T04:00:00                5            88        101546
# 29   2017-04-02T05:00:00                7            81        101608
# ..                   ...              ...           ...           ...
# 690  2017-04-29T18:00:00                8            69        101788
# 691  2017-04-29T19:00:00                7            74        101810
# 692  2017-04-29T20:00:00                6            84        101808
# 693  2017-04-29T21:00:00                5            89        101822
# 694  2017-04-29T22:00:00                4            89        101836
# 695  2017-04-29T23:00:00                4            86        101851
# 696  2017-04-30T00:00:00                2            94        101900
# 697  2017-04-30T01:00:00                2            97        101952
# 698  2017-04-30T02:00:00                2            94        101982
# 699  2017-04-30T03:00:00                2            93        102009
# 700  2017-04-30T04:00:00                3            97        102044
# 701  2017-04-30T05:00:00                4            93        102083
# 702  2017-04-30T06:00:00                5            94        102121
# 703  2017-04-30T07:00:00                5            91        102169
# 704  2017-04-30T08:00:00                6            85        101917
# 705  2017-04-30T09:00:00                7            81        102086
# 706  2017-04-30T10:00:00               11            86        102188
# 707  2017-04-30T11:00:00               13            76        102170
# 708  2017-04-30T12:00:00               15            62        102138
# 709  2017-04-30T13:00:00               22            45        102109
# 710  2017-04-30T14:00:00               23            41        102081
# 711  2017-04-30T15:00:00               18            53        102040
# 712  2017-04-30T16:00:00               16            59        102021
# 713  2017-04-30T17:00:00               13            71        102020
# 714  2017-04-30T18:00:00               12            78        102033
# 715  2017-04-30T19:00:00               11            82        102037
# 716  2017-04-30T20:00:00               10            88        102029
# 717  2017-04-30T21:00:00                9            92        102024
# 718  2017-04-30T22:00:00                9            96        102002
# 719  2017-04-30T23:00:00                8           101        101972
#
#      147_pressure  147_pm1  147_pm25  147_pm10  169_temperature  169_humidity  \
# 0          101829       69        65        94                6            89
# 1          101793       73        69        99                6            89
# 2          101760       76        72       103                5            91
# 3          101757       73        70       100                4            88
# 4          101755       74        71       101                4            91
# 5          101756       78        75       106                5            94
# 6          101765       67        64        93               10            81
# 7          101756       52        48        79               13            70
# 8          101722       40        38        65               16            54
# 9          101667       21        18        30               18            46
# 10         101624       16        13        20               18            42
# 11         101567       17        14        22               20            36
# 12         101500       16        13        21               21            31
# 13         101417       23        20        33               21            32
# 14         101346       15        11        18               21            34
# 15         101300       15        11        19               21            33
# 16         101296       14        11        18               20            35
# 17         101320       34        31        52               18            37
# 18         101368       33        30        51               15            51
# 19         101403       36        34        58               13            50
# 20         101420       30        27        46               12            55
# 21         101449       29        26        44               10            62
# 22         101481       31        27        46                8            66
# 23         101486       37        35        60                7            74
# 24         101468       49        46        76                7            75
# 25         101454       50        47        78                5            85
# 26         101451       48        45        76                5            84
# 27         101449       51        47        79                5            83
# 28         101472       46        43        74                4            86
# 29         101536       35        33        56                7            81
# ..            ...      ...       ...       ...              ...           ...
# 690        101729       44        43        73                9            76
# 691        101752       55        52        82                8            79
# 692        101750       74        70       100               10            85
# 693        101767       86        84       120                8            90
# 694        101784       63        61        95                4            89
# 695        101799       54        52        84                5            87
# 696        101850       81        80       115                1            89
# 697        101901       94        93       134                2            97
# 698        101932       98        97       140                4            94
# 699        101959       92        92       132                4            94
# 700        101996       97        97       139                3            97
# 701        102036       95        94       136                5            94
# 702        102073       84        84       120                5            94
# 703        102118       47        46        75                6            90
# 704        101846       30        28        45                7            87
# 705        102002       26        29        37                9            81
# 706        102136       28        31        42               18            70
# 707        102116       27        30        40               19            66
# 708        102079       25        26        35               18            68
# 709        102037       27        30        39               17            69
# 710        102001       27        30        40               17            71
# 711        101969       24        25        33               17            67
# 712        101955       25        26        34               17            74
# 713        101956       27        30        39               16            73
# 714        101974       31        34        48               15            76
# 715        101984       41        45        67                9            81
# 716        101973       47        52        78                8            84
# 717        101972       49        54        81               10            88
# 718        101949       60        64        91                5            94
# 719        101920       63        67        94                0            96
#
#        ...     225_pressure  225_pm1  225_pm25  225_pm10  226_temperature  \
# 0      ...           101918       58        55        73                6
# 1      ...           101879       56        53        70                5
# 2      ...           101854       53        50        66                4
# 3      ...           101847       51        47        64                4
# 4      ...           101847       47        43        61                3
# 5      ...           101852       48        44        62                4
# 6      ...           101857       56        53        70                9
# 7      ...           101845       38        35        53               12
# 8      ...           101802       21        18        27               15
# 9      ...           101744       17        13        19               17
# 10     ...           101698       13        10        15               18
# 11     ...           101652       10         7         9               19
# 12     ...           101588       12         9        12               20
# 13     ...           101503       11         8        11               21
# 14     ...           101438       12         8        11               21
# 15     ...           101395       13         9        13               21
# 16     ...           101393       17        14        21               20
# 17     ...           101408       21        18        28               18
# 18     ...           101450       26        22        35               15
# 19     ...           101477       26        22        35               13
# 20     ...           101502       30        27        44               12
# 21     ...           101532       30        27        42               10
# 22     ...           101564       32        30        47                8
# 23     ...           101567       34        32        51                7
# 24     ...           101544       33        31        50                7
# 25     ...           101535       32        30        47                5
# 26     ...           101536       33        31        49                5
# 27     ...           101530       30        28        44                5
# 28     ...           101553       32        30        47                5
# 29     ...           101641       36        33        53                6
# ..     ...              ...      ...       ...       ...              ...
# 690    ...           101792       29        26        39                7
# 691    ...           101817       28        25        40                6
# 692    ...           101819       38        35        52                5
# 693    ...           101847       46        42        60                4
# 694    ...           101854       46        42        60                3
# 695    ...           101870       61        60        78                3
# 696    ...           101906       64        62        81                1
# 697    ...           101970       65        64        82                1
# 698    ...           102004       76        76        99                2
# 699    ...           102033       78        79       104                2
# 700    ...           102058       79        80       104                2
# 701    ...           102105       79        80       104                4
# 702    ...           102142       75        76        98                4
# 703    ...           102188       43        41        59                5
# 704    ...           101920       30        29        44                6
# 705    ...           102102       20        21        25                8
# 706    ...           102199       18        19        22               14
# 707    ...           102181       16        16        18               15
# 708    ...           102156       13        13        14               16
# 709    ...           102122       18        18        20               16
# 710    ...           102087       22        23        26               16
# 711    ...           102043       22        24        28               16
# 712    ...           102013       18        17        20               15
# 713    ...           102020       21        22        25               14
# 714    ...           102035       37        40        50               13
# 715    ...           102043       27        29        36               12
# 716    ...           102035       30        33        42               11
# 717    ...           102033       35        38        51               11
# 718    ...           102011       35        38        51               10
# 719    ...           101987       38        41        56                9
#
#      226_humidity  226_pressure  226_pm1  226_pm25  226_pm10
# 0              89        101904       32        31        53
# 1              89        101867       29        27        46
# 2              93        101833       24        21        35
# 3              89        101829       23        20        33
# 4              93        101827       26        23        37
# 5              93        101834       35        34        57
# 6              80        101841       41        39        66
# 7              67        101833       31        28        49
# 8              50        101794       19        16        26
# 9              42        101742       13        10        16
# 10             39        101692       13        11        17
# 11             33        101633       12         9        15
# 12             29        101559       11         9        15
# 13             30        101480       12        10        16
# 14             31        101411       12        10        16
# 15             31        101371       12        10        15
# 16             32        101376       11         9        14
# 17             34        101395       18        15        24
# 18             48        101438       25        22        35
# 19             48        101471       37        35        58
# 20             54        101487       28        26        44
# 21             60        101523       24        20        34
# 22             65        101554       21        18        29
# 23             73        101553       24        21        35
# 24             74        101529       23        20        32
# 25             85        101505       18        16        25
# 26             84        101508       20        17        27
# 27             84        101511       26        23        39
# 28             87        101528       21        18        29
# 29             82        101597       17        14        23
# ..            ...           ...      ...       ...       ...
# 690            68        101776       54        53        78
# 691            72        101799       62        62        90
# 692            80        101796       78        79       110
# 693            86        101809       76        77       107
# 694            88        101834       74        75       105
# 695            83        101846       79        80       112
# 696            93        101898       78        80       112
# 697            96        101953       75        76       106
# 698            92        101988       71        72       102
# 699            92        102011       69        70        99
# 700            96        102048       67        69        98
# 701            92        102087       69        71       100
# 702            93        102119       70        71       100
# 703            90        102168       39        38        62
# 704            84        101865       25        24        37
# 705            81        102068       18        20        25
# 706            79        102182       18        19        25
# 707            69        102157       18        20        25
# 708            64        102118       19        20        26
# 709            62        102077       22        24        31
# 710            62        102045       21        23        30
# 711            63        102009       19        20        26
# 712            68        101995       21        22        28
# 713            79        101999       26        28        37
# 714            84        102019       31        34        49
# 715            87        102024       39        44        64
# 716            94        102016       35        40        58
# 717            94        102014       39        44        65
# 718            99        101992       43        50        74
# 719           103        101962       42        48        71
#
# [720 rows x 144 columns]

# %% [markdown]
# ## 1.3 Date Time
#
# Most Engineering data are time series, handling date time is one of the commonly data type. However date time come in all kind of format and many time when read from file it is read in as text/string. We would learn how to convert to proper python date time so that we could easily perform further processing.
#
# Please refer to the below link for more on date time of Pandas:
#
# [https://pandas.pydata.org/pandas-docs/stable/generated/pandas.to_datetime.html](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.to_datetime.html)

# %% [markdown]
# ## Exercise 2
#
# Read in the lab3_date1.csv file into Pandas dataframe and preview the data.
#
# Clean the data to remove all null value.

# %%
import numpy as np
import pandas as pd

dd=pd.read_csv('lab3_dateT.csv')
dd.head()
#the Datetime is read in as string/text we need to convert them to proper datetime format
# Out:
#               Datetime  this  Values
# 0  2017-04-01T00:00:00   NaN       1
# 1  2017-04-01T01:00:00   NaN       2
# 2  2017-04-01T02:00:00   NaN       3
# 3  2017-04-01T03:00:00   NaN       4
# 4  2017-04-01T04:00:00   NaN       5

# %%
dd=dd.dropna(axis='columns')
dd.head()
# Out:
#               Datetime  Values
# 0  2017-04-01T00:00:00       1
# 1  2017-04-01T01:00:00       2
# 2  2017-04-01T02:00:00       3
# 3  2017-04-01T03:00:00       4
# 4  2017-04-01T04:00:00       5

# %% [markdown]
# Lets proceed to convert the Datetime read in (still a string)  to proper Python date time.

# %%
dd['Datetime']=pd.to_datetime(dd['Datetime'],format='%Y-%m-%dT%H:%M:%S',utc=True) #convert string to datetime
#Note: the format string is provided as the date and time are seperated by 'T' rather than space
dd.head()
# Out:
#                    Datetime  Values
# 0 2017-04-01 00:00:00+00:00       1
# 1 2017-04-01 01:00:00+00:00       2
# 2 2017-04-01 02:00:00+00:00       3
# 3 2017-04-01 03:00:00+00:00       4
# 4 2017-04-01 04:00:00+00:00       5

# %%
#convert the date time back to epoch notice that the epeoch is in us 1/1,000,000 second)
print(dd['Datetime'].astype(np.int64).head())
# Out:
# 0    1491004800000000000
# 1    1491008400000000000
# 2    1491012000000000000
# 3    1491015600000000000
# 4    1491019200000000000
# Name: Datetime, dtype: int64

# %%
dd.set_index('Datetime', inplace=True)  # set the date time as index
dd.head()
# Out:
#                            Values
# Datetime
# 2017-04-01 00:00:00+00:00       1
# 2017-04-01 01:00:00+00:00       2
# 2017-04-01 02:00:00+00:00       3
# 2017-04-01 03:00:00+00:00       4
# 2017-04-01 04:00:00+00:00       5

# %%
#lets plot our first graph just for fun
import matplotlib.pyplot as plt
plt.plot(dd)
plt.show()

# %%
#lets see how we convert from unix timestamp to python datetime then back to unix timestamp
from datetime import timezone
t=pd.to_datetime(1539259685,unit='s')   #Thursday, 11 October 2018 12:08:05
print(t)
print(t.timestamp())  #back to unix timestamp
# Out:
# 2018-10-11 12:08:05
# 1539259685.0

# %% [markdown]
# ## Exercise 3
#
# Load remote_v3.csv and set the datetime to index (firstly convert to python datetime) then plot the scatter plot.

# %%
import numpy as np
import pandas as pd
from datetime import timezone
dd=pd.read_csv('remote_v3.csv')
dd.head()
# Out:
#                         time  value
# 0  2017-08-11 00:00:00+08:00    0.0
# 1  2017-08-11 00:03:00+08:00    0.0
# 2  2017-08-11 00:06:00+08:00    0.0
# 3  2017-08-11 00:09:00+08:00    0.0
# 4  2017-08-11 00:12:00+08:00    0.0

# %%
dd['time']=pd.to_datetime(dd['time'],format='%Y-%m-%d %H:%M:%S+08:00',utc=True) #convert string to datetime
#tt=pd.to_datetime(dd['time'],format='%Y-%m-%d %H:%M:%S',utc=True) #convert string to datetime
#dd['time']=(dd['time'].astype(np.int64)) /100000000   #convert to second
dd.set_index('time', inplace=True)
dd.head()
# Out:
#                            value
# time
# 2017-08-11 00:00:00+00:00    0.0
# 2017-08-11 00:03:00+00:00    0.0
# 2017-08-11 00:06:00+00:00    0.0
# 2017-08-11 00:09:00+00:00    0.0
# 2017-08-11 00:12:00+00:00    0.0

# %%
import matplotlib.pyplot as plt
plt.plot(dd)
plt.show()

# %%
aa= dd['2017-08-11 09:00:00':'2017-08-11 23:00:00']
plt.plot(aa)
plt.show()
